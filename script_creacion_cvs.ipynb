# %% [markdown]
# # Script para extracción de información de las CVs

# %% [markdown]
# ##### Obtener librerías necesarias

# %%
import os
import fitz  # PyMuPDF for PDFs
import pytesseract
from PIL import Image
import pandas as pd
import re
import spacy
import pdfplumber
from rapidfuzz import process, fuzz
from dateutil import parser
from collections import Counter
import io
import numpy as np
import cv2
import PyPDF2
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
import language_tool_python
from spellchecker import SpellChecker
from datetime import datetime, timedelta

# %% [markdown]
# ##### Importar SpaCy para NLP
# Spacy es una librería de python que permite por medio de modelos de lenguaje pre-importados realizar análisis de texto, identificando palabras, nombres, lugares, objetos, verbos, adjetivos y la relación entre los mismos.
#
# En este caso, importamos el modelo pre-entrenado en inglés, lo que requiere que todas las CVs a procesar estén en este idioma.

# %%
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# #### Obtenemos las CVs a estudiar

# %%
hv_dir_exitosas = "hojas_de_vida_copy/Paso"
hv_dir_noexitosas = "hojas_de_vida_copy/No paso"

# %% [markdown]
# #### Extraer el texto

# %%
def extraer_texto_pdf(pdf_path):
    """Extrae texto de un PDF."""
    with pdfplumber.open(pdf_path) as pdf:
        texto = "\n".join([page.extract_text() or "" for page in pdf.pages])
    return texto

# %% [markdown]
# ## Estructura y Organización

# %% [markdown]
# #### Extensión del CV: Contar páginas

# %%
def contar_paginas(pdf_path):
    with fitz.open(pdf_path) as pdf:
        return len(pdf)

# %% [markdown]
# ### Uso de secciones bien definidas - Extraer secciones

# %%
def detectar_secciones(texto):
    """Detecta si el CV tiene secciones bien definidas."""
    secciones_dict = {
        "education": ["education", "academic background", "studies", "university studies"],
        "work_experience": ["experience", "work experience", "employment history", "career history"],
        "skills": ["skills", "technical skills", "competencies"],
        "certifications": ["certifications", "licenses", "accreditations"],
        "achievements": ["achievements", "accomplishments", "milestones"],
        "professional_profile": ["profile", "summary", "about me", "professional summary", "objective"],
        "languages": ["languages", "linguistic skills", "spoken languages"],
        "projects": ["projects", "case studies", "portfolio"],
        "publications": ["publications", "research papers", "articles", "books"],
        "training_courses": ["training", "courses", "workshops", "seminars", "courses and seminars", "Other Studies"],
        "volunteer_work": ["volunteer work", "volunteering", "community service", "social impact", "non-profit"],
    }

    lineas = texto.split("\n")
    secciones_detectadas = {seccion: False for seccion in secciones_dict}  # Inicializamos todas en False

    for i, linea in enumerate(lineas):
        linea_limpia = re.sub(r"\s+", " ", linea.strip())  # 🔹 Limpia espacios innecesarios

        for seccion, sinonimos in secciones_dict.items():
            resultado = process.extractOne(linea_limpia, sinonimos, scorer=fuzz.partial_ratio)
            if resultado:
                mejor_coincidencia, score, *_ = resultado

                if score >= 75:  # 🔹 Bajamos umbral a 75 para mayor flexibilidad
                    secciones_detectadas[seccion] = True  # Marcamos como encontrada
                    break  # Pasamos a la siguiente línea para evitar duplicados

    return secciones_detectadas
# Out:
# Secciones detectadas: {'education': True, 'work_experience': True, 'skills': True, 'certifications': True, 'achievements': False, 'professional_profile': True, 'languages': True, 'projects': True, 'publications': True, 'training_courses': False, 'volunteer_work': False}

# %% [markdown]
# ### Orden Cronológico o funcional de la información

# %%
# Expresiones regulares mejoradas para fechas
# Expresiones regulares para detectar fechas en distintos formatos
patrones_fechas = [
    r"\b\d{4}\b",  # Años sueltos (ej. 2020)
    r"\b(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]* \d{4}\b",  # Mes Año (ej. Mar 2020)
    r"\b(?:Enero|Febrero|Marzo|Abril|Mayo|Junio|Julio|Agosto|Septiembre|Octubre|Noviembre|Diciembre)\s\d{4}\b",  # Español
    r"\b\d{1,2}/\d{1,2}/\d{4}\b",  # dd/mm/yyyy
    r"\b\d{1,2}-\d{1,2}-\d{4}\b",  # dd-mm-yyyy
    r"\b\d{4}[-–]\d{4}\b",  # Rango de años (ej. 2018-2020)
    r"\b\d{4}[-–]\s*(?:Presente|Actual|Present)\b",  # Ejemplo: 2019 - Presente
]

def extraer_fechas(texto):
    """Extrae fechas de un texto usando regex y NLP, y las ordena correctamente."""
    fechas_encontradas = set()

    # Extraer fechas con regex
    for patron in patrones_fechas:
        coincidencias = re.findall(patron, texto, re.IGNORECASE)
        fechas_encontradas.update(coincidencias)

    # Extraer fechas con spaCy
    doc = nlp(texto)
    for ent in doc.ents:
        if ent.label_ == "DATE":
            fechas_encontradas.add(ent.text)

    # Convertir fechas a datetime y manejar "Presente"
    fechas_convertidas = []
    fechas_texto = []

    for fecha in fechas_encontradas:
        try:
            if any(word in fecha.lower() for word in ["presente", "actual", "present"]):
                fecha_convertida = datetime.today() + timedelta(days=365)  # Fecha ficticia para ordenación
                fechas_texto.append((fecha, fecha_convertida))  # Guardamos la relación texto-fecha
            else:
                fecha_convertida = parser.parse(fecha, fuzzy=True)
                fechas_convertidas.append(fecha_convertida)
        except:
            pass

    # Ordenar fechas datetime
    fechas_convertidas.sort(reverse=True)

    # Ordenar las fechas "Presente" después de todas las fechas reales
    fechas_texto.sort(key=lambda x: x[1], reverse=True)

    # Combinar y devolver el resultado, pero reemplazando la fecha ficticia con el texto original
    return fechas_convertidas + [ft[0] for ft in fechas_texto]

def determinar_orden_cronologico(texto):
    """Determina si el CV sigue un orden cronológico inverso o no."""
    fechas = extraer_fechas(texto)

    if not fechas or len(fechas) < 2:
        return "No se detectaron suficientes fechas"

    # Verificamos si las fechas están en orden descendente (cronológico inverso)
    fechas_numericas = [f for f in fechas if isinstance(f, datetime)]  # Filtrar solo fechas datetime

    if fechas_numericas == sorted(fechas_numericas, reverse=True):
        return "Orden Cronológico"
    else:
        return "Orden Funcional"

pdf_file = "hojas_de_vida_copy/Paso/KevinParraResume.pdf"
texto_cv = extraer_texto_pdf(pdf_file)  # Usa tu función existente
resultado = determinar_orden_cronologico(texto_cv)
print(f"El CV sigue un: {resultado}")
# Out:
# El CV sigue un: Orden Cronológico

# %% [markdown]
# ### Uso de viñetas (bullet-points) o parrafos para escribir la información

# %%
def detectar_formato_texto(texto):
    """
    Determina si el CV usa principalmente viñetas, párrafos o es mixto.
    """
    lineas = texto.split("\n")
    total_lineas = len([l for l in lineas if l.strip()])
    lineas_vinetas = 0
    lineas_parrafos = 0

    # Expresión regular para detectar viñetas
    regex_vinetas = r"^(•|-|\*|▪|○|\d+\.)\s+"

    for linea in lineas:
        linea_limpia = linea.strip()

        if not linea_limpia:
            continue  # Ignorar líneas vacías

        palabras = linea_limpia.split()
        num_palabras = len(palabras)
        num_caracteres = len(linea_limpia)

        # Si la línea coincide con una viñeta, sumamos al contador de viñetas
        if re.match(regex_vinetas, linea_limpia) or num_palabras < 8:
            lineas_vinetas += 1
        elif num_caracteres > 30 and num_palabras > 12:  # Mayor umbral para considerar párrafo
            lineas_parrafos += 1

    # Decidir clasificación según la proporción
    if lineas_vinetas / total_lineas > 0.5:
        return "Viñetas"
    elif lineas_parrafos / total_lineas > 0.5:
        return "Párrafos"
    else:
        return "Mixto"
# Out:
# Formato del CV: Viñetas

# %% [markdown]
# ## Diseño y Estilo de la CV

# %% [markdown]
# ### Tipografía y tamaño de fuente (legibilidad, uso de negritas o cursiva)

# %%
import pdfplumber
from collections import Counter

def analizar_tipografia(pdf_path):
    """
    Extrae información sobre la tipografía, tamaño de fuente y uso de negritas/cursivas en un PDF.
    """
    with pdfplumber.open(pdf_path) as pdf:
        fuentes = []
        negritas = 0
        cursivas = 0

        for page in pdf.pages:
            for block in page.extract_words(extra_attrs=["fontname", "size"]):
                fuente = block["fontname"]
                tamano = round(block["size"], 1)  # Redondeamos el tamaño de fuente

                fuentes.append((fuente, tamano))

                # Detectar negrita y cursiva (puede variar según el PDF)
                if "Bold" in fuente or "Black" in fuente:
                    negritas += 1
                if "Italic" in fuente or "Oblique" in fuente:
                    cursivas += 1

        # Análisis de fuentes y tamaños más comunes
        fuente_mas_comun, tamano_mas_comun = Counter(fuentes).most_common(1)[0][0]

        # Evaluar legibilidad
        legibilidad = "Buena" if tamano_mas_comun >= 10 else "Deficiente"

        return {
            "Fuente principal": fuente_mas_comun,
            "Tamaño de fuente más usado": tamano_mas_comun,
            "Legibilidad": legibilidad,
            "Uso de negritas": negritas,
            "Uso de cursivas": cursivas
        }
# Out:
# Análisis de tipografía: {'Fuente principal': 'UGGCUJ+AvenirNext-UltraLight', 'Tamaño de fuente más usado': 12.0, 'Legibilidad': 'Buena', 'Uso de negritas': 71, 'Uso de cursivas': 0}

# %% [markdown]
# ### Uso de colores y gráficos

# %%
def analizar_colores_graficos(pdf_path):
    """
    Analiza un PDF en busca de:
    - Uso de colores en texto y gráficos (excluyendo azul de enlaces y fondo blanco).
    - Porcentaje de color real en la CV.
    - Cantidad de imágenes o gráficos.
    """
    cantidad_imagenes = 0
    total_paginas = 0
    color_detectado = 0
    color_total = 0

    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            total_paginas += 1
            cantidad_imagenes += len(page.images)  # Contar imágenes

            # Convertir página a imagen para análisis de color
            img = np.array(page.to_image(resolution=150).annotated)
            img_hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)

            # Crear máscara para detectar colores (excluir blancos y grises)
            lower = np.array([0, 50, 50])  # No contar colores con baja saturación (grisáceos)
            upper = np.array([179, 255, 255])
            mask = cv2.inRange(img_hsv, lower, upper)
            porcentaje_color = (np.sum(mask > 0) / mask.size) * 100  # Porcentaje de color real

            # Si más del 90% de la página es color, asumimos que es un fondo y no cuenta
            if porcentaje_color < 90:
                color_detectado += porcentaje_color

            color_total += porcentaje_color

    # Promediar el porcentaje de color en todas las páginas
    porcentaje_color_promedio = round(color_detectado / total_paginas, 2) if total_paginas > 0 else 0

    return {
        "Uso de colores (excluyendo fondo blanco y links)": "Sí" if porcentaje_color_promedio > 0 else "No",
        "Porcentaje de color real en la CV": f"{porcentaje_color_promedio}%",
        "Cantidad de imágenes o gráficos": cantidad_imagenes
    }
# Out:
# Análisis de colores y gráficos: {'Uso de colores (excluyendo fondo blanco y links)': 'Sí', 'Porcentaje de color real en la CV': '0.2%', 'Cantidad de imágenes o gráficos': 2}

# %% [markdown]
# ### Distribución del espacio en la hoja - Densidad de la información vs espacios en blanco

# %%
def calcular_densidad_informacion(pdf_path):
    """
    Calcula el porcentaje total de ocupación de texto en el documento completo.
    Retorna un único valor porcentual representando la densidad de información.
    """
    with pdfplumber.open(pdf_path) as pdf:
        porcentajes = []

        for page in pdf.pages:
            bbox = page.bbox  # Dimensiones de la página (ancho, alto)
            ancho, alto = bbox[2], bbox[3]
            area_total = ancho * alto

            palabras = page.extract_words()
            if palabras:
                # Calcular área ocupada por texto
                area_texto = sum((word['x1'] - word['x0']) * (word['bottom'] - word['top']) for word in palabras)
                porcentaje_texto = (area_texto / area_total) * 100
                porcentajes.append(porcentaje_texto)

        # Calcular densidad total como promedio de todas las páginas
        densidad_total = sum(porcentajes) / len(porcentajes) if porcentajes else 0

    return round(densidad_total, 2)
# Out:
# 20.76

# %% [markdown]
# ### Consistencia en el formato - Alineación, tamaños de títulos, márgenes

# %%
def analizar_formato_cv(pdf_path):
    """
    Evalúa la consistencia del formato en términos de alineación, tamaños de títulos y márgenes.
    """
    with pdfplumber.open(pdf_path) as pdf:
        alineaciones = []
        tamaños_fuente = []
        margenes = []

        for page in pdf.pages:
            words = page.extract_words(extra_attrs=["x0", "x1", "top", "fontname", "size"])
            if not words:
                continue

            # Detectar alineaciones (izquierda, derecha, centrado, justificado)
            for word in words:
                if word["x0"] < page.width * 0.15:
                    alineaciones.append("Izquierda")
                elif word["x1"] > page.width * 0.85:
                    alineaciones.append("Derecha")
                elif abs(word["x0"] - (page.width - word["x1"])) < 10:
                    alineaciones.append("Centrado")
                else:
                    alineaciones.append("Justificado")

                tamaños_fuente.append(round(word["size"], 1))

            # Calcular márgenes (mínima distancia del texto al borde)
            margen_izq = min(word["x0"] for word in words)
            margen_der = page.width - max(word["x1"] for word in words)
            margen_top = min(word["top"] for word in words)
            margen_bottom = page.height - max(word["top"] for word in words)
            margenes.append((margen_izq, margen_der, margen_top, margen_bottom))

        # Determinar consistencia
        alineacion_mas_comun = Counter(alineaciones).most_common(1)[0][0]
        tamaño_mas_comun = Counter(tamaños_fuente).most_common(1)[0][0]
        variabilidad_tamaños = len(set(tamaños_fuente)) > 3  # Si hay más de 3 tamaños diferentes, se considera inconsistente
        variabilidad_margenes = len(set(margenes)) > 2  # Si hay más de 2 configuraciones de márgenes, se considera inconsistente

        return {
            "Alineación principal": alineacion_mas_comun,
            "Tamaño de fuente más usado": tamaño_mas_comun,
            "Consistencia de tamaños": "Inconsistente" if variabilidad_tamaños else "Consistente",
            "Consistencia de márgenes": "Inconsistente" if variabilidad_margenes else "Consistente"
        }
# Out:
# Análisis de formato: {'Alineación principal': 'Justificado', 'Tamaño de fuente más usado': 12.0, 'Consistencia de tamaños': 'Consistente', 'Consistencia de márgenes': 'Consistente'}

# %% [markdown]
# ## Claridad y Lenguaje

# %% [markdown]
# ### Cantidad de palabras y densidad textual

# %%
def calcular_palabras_y_densidad(pdf_path):
    """
    Calcula la cantidad de palabras y la densidad textual en un CV en PDF.
    """
    total_palabras = 0
    total_area_texto = 0
    total_area_pagina = 0

    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            texto = page.extract_text()
            if texto:
                total_palabras += len(texto.split())  # Contar palabras
            total_area_pagina += page.width * page.height  # Área total de la página

            for block in page.extract_words(extra_attrs=["x0", "x1", "top", "bottom"]):
                ancho = block["x1"] - block["x0"]
                alto = block["bottom"] - block["top"]
                total_area_texto += ancho * alto  # Sumar áreas de bloques de texto

    # Calcular densidad textual como proporción del área de texto en la página
    densidad_textual = (total_area_texto / total_area_pagina) * 100 if total_area_pagina > 0 else 0

    return {
        "Cantidad de palabras": total_palabras,
    }
# Out:
# Análisis de texto: {'Cantidad de palabras': 1838}

# %% [markdown]
# ### Presencia de errores ortográficos o gramaticales

# %%
# def detectar_errores_ortograficos_gramaticales(pdf_path, idioma="en"):
#     """
#     Detecta errores ortográficos y gramaticales en un CV en PDF.
#     """
#
#     # Inicializar correctores
#     spell = SpellChecker(language=idioma)
#     tool = language_tool_python.LanguageToolPublicAPI(idioma)
#
#     texto_completo = ""
#
#     # Extraer texto del PDF
#     with pdfplumber.open(pdf_path) as pdf:
#         for page in pdf.pages:
#             texto = page.extract_text()
#             if texto:
#                 texto = texto.replace("\n", " ")  # Reemplazar saltos de línea por espacios
#                 texto = re.sub(r"\s+", " ", texto)  # Normalizar espacios múltiples a uno solo
#                 texto = re.sub(r"([a-zA-ZáéíóúüñÁÉÍÓÚÜÑ])([.,])([a-zA-ZáéíóúüñÁÉÍÓÚÜÑ])", r"\1\2 \3", texto)
#                 texto_completo += texto + " "
#
#     # 🔹 Normalizar texto (eliminar puntuación y convertir a minúsculas)
#     texto_completo = re.sub(r"[^a-zA-ZáéíóúüñÁÉÍÓÚÜÑ ]", "", texto_completo.lower())
#
#     # 🔹 Separar palabras y eliminar las demasiado cortas
#     palabras = [palabra for palabra in texto_completo.split() if len(palabra) > 2]
#
#     # 🔹 Revisar errores ortográficos (palabras desconocidas)
#     errores_ortograficos = {palabra: spell.correction(palabra) for palabra in spell.unknown(palabras)}
#
#     # 🔹 Dividir el texto en fragmentos más pequeños para LanguageTool
#     oraciones = texto_completo.split(". ")  # Dividir en oraciones
#     errores_gramaticales = sum(len(tool.check(ora)) for ora in oraciones)  # Contar errores totales
#
#     return {
#         "Errores ortográficos detectados": len(errores_ortograficos),
#         "Ejemplo de errores ortográficos": dict(list(errores_ortograficos.items())[:10]),  # Solo muestra 10
#         "Cantidad de errores gramaticales": errores_gramaticales,
#     }
#
# # 📌 Ejemplo de uso
# pdf_file = "hojas_de_vida_copy/Paso/CVJCOC.pdf"
# resultado_errores = detectar_errores_ortograficos_gramaticales(pdf_file)
# print(f"Errores detectados: {resultado_errores}")


"""Por ahora no se avanzará con este ya que es muy exigente con el sistema y muy poco precisa"""
# Out:
# 'Por ahora no se avanzará con este ya que es muy exigente con el sistema y muy poco precisa'

# %% [markdown]
# ### Creamos un diccionario con terminos técnicos y palabras clave
# Esto para identificar la cantidad de términos y keywords que un candidato puede usar en su CV

# %%
TECH_TERMS = {
        # Lenguajes de programación
        "Java", "Spring Boot", "Hibernate", "JPA", "Java EE",
        "JavaScript", "TypeScript", "React", "Angular", "Vue",
        "Node.js", "Express.js", "NestJS", "HTML", "CSS", "SASS",
        "Python", "Django", "Flask", "FastAPI", "C#", ".NET", "ASP.NET",
        "Ruby", "Rails", "PHP", "Laravel", "Go", "Rust", "Kotlin", "Swift",

        # Bases de datos
        "SQL", "PostgreSQL", "MySQL", "MariaDB", "MongoDB", "NoSQL",
        "Redis", "Elasticsearch", "Firebase", "DynamoDB", "GraphQL",

        # DevOps y Cloud
        "Docker", "Kubernetes", "AWS", "Azure", "GCP", "Terraform",
        "Jenkins", "CI/CD", "GitHub Actions", "Ansible", "Linux",

        # Arquitectura y Metodologías
        "Microservices", "API", "REST", "SOAP", "GraphQL",
        "Agile", "Scrum", "Kanban", "DDD", "TDD", "SOLID", "Clean Architecture",

        # Seguridad y Testing
        "OWASP", "JWT", "OAuth", "SAML", "Penetration Testing",
        "Selenium", "JUnit", "Mockito", "Jest", "Cypress",

        # Otros conceptos importantes
        "Multithreading", "Concurrency", "Asynchronous Programming",
        "WebSockets", "Event-Driven Architecture", "Kafka", "RabbitMQ",
        "gRPC", "WebAssembly"
}

# %% [markdown]
# ### Uso de lenguaje técnico o genérico

# %%
def analyze_technical_language(pdf_path):
    """Extrae texto de un PDF y calcula el porcentaje de lenguaje técnico vs genérico."""

    try:
        with open(pdf_path, "rb") as file:
            reader = PyPDF2.PdfReader(file)
            text = " ".join([page.extract_text() for page in reader.pages if page.extract_text()])
    except Exception as e:
        return f"Error al leer el PDF: {e}"

    words = re.findall(r'\b\w+\b', text)
    if not words:
        return "No se pudo extraer texto del PDF"

    total_words = len(words)
    tech_words = sum(1 for word in words if word in TECH_TERMS)

    tech_ratio = (tech_words / total_words) * 100 if total_words > 0 else 0

    return tech_ratio

# %% [markdown]
# ## Personalización y adaptabilidad

# %% [markdown]
# ### Inclusión de enlaces a portafolio o redes sociales

# %%
def extract_links_from_cv(pdf_path):
    patterns = {
        "LinkedIn": r"https?:\/\/(?:www\.)?linkedin\.com\/[a-zA-Z0-9\-_/]+",
        "GitHub": r"https?:\/\/(?:www\.)?github\.com\/[a-zA-Z0-9\-_/]+",
        "Website": r"https?:\/\/(?:www\.)?[a-zA-Z0-9\-.]+\.[a-zA-Z]{2,6}(?:\/[a-zA-Z0-9\-_/]*)?",
    }

    # Extraer texto del PDF
    doc = fitz.open(pdf_path)
    text = " ".join([page.get_text("text", flags=1).replace("\n", " ") for page in doc])

    # Buscar LinkedIn y GitHub
    linkedin_found = bool(re.search(patterns["LinkedIn"], text))
    github_found = bool(re.search(patterns["GitHub"], text))

    # Buscar cualquier otro enlace
    all_extracted_links = set(re.findall(patterns["Website"], text))

    # Filtrar para que no incluya LinkedIn ni GitHub
    personal_website_found = any(link for link in all_extracted_links if not (
        re.match(patterns["LinkedIn"], link) or re.match(patterns["GitHub"], link)
    ))

    return {
        "LinkedIn": linkedin_found,
        "GitHub": github_found,
        "Personal Website": personal_website_found
    }
# Out:
# {'LinkedIn': True, 'GitHub': False, 'Personal Website': False}

# %% [markdown]
# ## Información visual y Complementaria

# %% [markdown]
# ### Incorporación de foto o ausencia de la misma

# %%
def tiene_foto(pdf_path):
    doc = fitz.open(pdf_path)

    for page in doc:
        if page.get_images(full=True):
            return True  # Si encuentra al menos una imagen, retorna True

    return False
# Out:
# True

# %% [markdown]
# ### Presencia de íconos o elementos gráficos

# %%
def detectar_elementos_graficos(pdf_path, umbral_area=2000, max_elementos=3):
    """
    Detecta si un CV en PDF tiene elementos gráficos significativos (líneas gruesas, rectángulos, dibujos vectoriales).

    Parámetros:
        - pdf_path: Ruta del archivo PDF.
        - umbral_area: Área mínima para considerar un elemento gráfico como relevante.
        - max_elementos: Número mínimo de elementos grandes para considerar que hay gráficos.

    Retorna:
        - Un diccionario con 'Tiene_elementos_graficos' como True o False.
    """
    elementos_grandes = 0
    doc = fitz.open(pdf_path)

    for page in doc:
        drawings = page.get_drawings()
        for draw in drawings:
            bbox = draw["rect"]  # Bounding box (x0, y0, x1, y1)
            width = bbox[2] - bbox[0]
            height = bbox[3] - bbox[1]
            area = width * height  # Calculamos el área del elemento gráfico

            if area > umbral_area:  # Consideramos solo elementos suficientemente grandes
                elementos_grandes += 1
                if elementos_grandes >= max_elementos:
                    return {"Tiene_elementos_graficos": True}

    return {"Tiene_elementos_graficos": False}
# Out:
# {'Tiene_elementos_graficos': False}

# %% [markdown]
# ## Extracción de la información

# %%
def procesar_CVs_en_carpeta(carpeta):
    """
    Procesa todos los archivos PDF en la carpeta especificada y extrae información clave de cada CV.

    Parámetros:
        carpeta (str): Ruta de la carpeta donde se encuentran los CVs en formato PDF.

    Retorna:
        DataFrame con la información extraída de cada CV.
    """
    datos_CVs = []

    for archivo in os.listdir(carpeta):
        if archivo.endswith(".pdf"):
            ruta_pdf = os.path.join(carpeta, archivo)
            print(f"Procesando: {archivo}")

            try:
                # Extraer texto
                texto = extraer_texto_pdf(ruta_pdf)

                # Obtener número de páginas
                num_paginas = contar_paginas(ruta_pdf)

                # Detectar secciones
                secciones_detectadas = detectar_secciones(texto)

                # Determinar el orden cronológico o funcional
                orden_cronologico = determinar_orden_cronologico(texto)

                # Detectar formato de escritura (viñetas o párrafos)
                formato_texto = detectar_formato_texto(texto)

                # Analizar tipografía y legibilidad
                tipografia_info = analizar_tipografia(ruta_pdf)

                # Analizar uso de colores y gráficos
                colores_graficos = analizar_colores_graficos(ruta_pdf)

                # Calcular densidad de información
                densidad_info = calcular_densidad_informacion(ruta_pdf)

                # Analizar consistencia de formato
                formato_cv = analizar_formato_cv(ruta_pdf)

                # Calcular cantidad de palabras
                palabras_info = calcular_palabras_y_densidad(ruta_pdf)

                # Lenguaje Tecnico
                lenguaje_tecnico = analyze_technical_language(ruta_pdf)

                #Enlaces
                enlaces = extract_links_from_cv(ruta_pdf)


                # Crear diccionario con los datos extraídos
                datos_cv = {
                    "Archivo": archivo,
                    "Páginas": num_paginas,
                    **secciones_detectadas,
                    "Orden Cronológico": orden_cronologico,
                    "Formato de Texto": formato_texto,
                    "Densidad de Información": densidad_info,
                    "Cantidad de Palabras": palabras_info["Cantidad de palabras"],
                    " % Lenguaje de Técnico":lenguaje_tecnico,
                    "LinkedIn":enlaces["LinkedIn"],
                    "GitHub":enlaces["GitHub"],
                    "Personal Website":enlaces["Personal Website"],
                    **tipografia_info,
                    **colores_graficos,
                    **formato_cv
                }

                # Agregar resultados a la lista
                datos_CVs.append(datos_cv)


            except Exception as e:
                print(f"Error al procesar {archivo}: {e}")

    # Convertir resultados en DataFrame
    df_resultados = pd.DataFrame(datos_CVs)

    return df_resultados

# %%
hv_dir_ejemplo = "Ejemplos/Documentos Ejemplo"
df_ejemplo = procesar_CVs_en_carpeta(hv_dir_ejemplo)
# Out:
# Procesando: sample_cv_for_manatal_manual.pdf

# %%
df_ejemplo
# Out:
#                             Archivo  Páginas  education  work_experience  \
# 0  sample_cv_for_manatal_manual.pdf        2       True             True
#
#    skills  certifications  achievements  professional_profile  languages  \
# 0   False           False         False                  True       True
#
#    projects  ...  Tamaño de fuente más usado  Legibilidad  Uso de negritas  \
# 0      True  ...                        11.0        Buena               18
#
#   Uso de cursivas Uso de colores (excluyendo fondo blanco y links)  \
# 0              22                                               Sí
#
#    Porcentaje de color real en la CV  Cantidad de imágenes o gráficos  \
# 0                              0.27%                                0
#
#    Alineación principal  Consistencia de tamaños  Consistencia de márgenes
# 0           Justificado              Consistente               Consistente
#
# [1 rows x 32 columns]

# %%
df_CVs_exitosos = procesar_CVs_en_carpeta(hv_dir_exitosas)
df_CVs_no_exitosos = procesar_CVs_en_carpeta(hv_dir_noexitosas)
# Out:
# Procesando: Lucas Visentin - Resume.pdf
# Procesando: CV Milton Ivan Martinez Gonzalez (1).pdf
# Procesando: CV - Andrea Martins.pdf
# Procesando: Resume Hector Bedoya L.pdf
# Procesando: 985269fa-a528-46aa-bc9c-403ee23fbcd3_CV Felipe Feres .pdf
# Procesando: CV-JDC-EN (2).pdf
# Error al procesar CV-JDC-EN (2).pdf: '<' not supported between instances of 'datetime.datetime' and 'str'
# Procesando: Miguel Santos Java Developer (1).pdf
# Procesando: denis_cv_en_new.pdf
# Procesando: CV Marcio Galvao.pdf
# Error al procesar CV Marcio Galvao.pdf: '<' not supported between instances of 'datetime.datetime' and 'str'
# Procesando: Damian Bejarano CV - Frontend Developer (1).pdf
# Procesando: CV_Fabio_Andres_Mora_Ossa.pdf
# Procesando: EN-FRANCISCO BELTRAN.pdf
# Procesando: CV Jorge Caro - Fullstack Engineer - Tenant Evaluation - Remoti.pdf
# Procesando: EN_ResumeJorgeAbreu.pdf
# Procesando: KevinParraResume.pdf
# Error al procesar KevinParraResume.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Erik Henrique-Frontend Engineer-Betsson Malta-Remoti.pdf
# Procesando: Yekaterina Muradyan (1).pdf
# Procesando: LucasRodriguesDaSilva.pdf
# Procesando: frontend-resume (1) (1).pdf
# Procesando: CV  Camilo Andrés Moreno Laverde - Frontend engineer - Betsson Malta - Remoti.pdf
# Procesando: CV JOHN MATEUS .pdf
# Procesando: 11686212-CV-Jorge Vidal.pdf
# Procesando: CV - Juan Felipe Betancur Cano-  Frontend engineer - Betsson Malta - Remoti.pdf
# Procesando: }.pdf
# Procesando: 14503315-CV - Henry Luis Gomez Ortiz [En] (1) (1).pdf
# Procesando: 2. Omar Lopez.pdf
# Procesando: Jose Ripoll.pdf
# Procesando: CV-EN-Gabriel-Umbelino.pdf
# Procesando: DEIVID DIMAS_en.pdf
# Procesando: Samir Cabrera CV 2022 (1).pdf
# Procesando: 8709657E-B844-4E72-8789-15004BEA3FB0 (1).pdf
# Procesando: hoja_de_vida_oscar_sanabria_fc.pdf
# Procesando: CV- Ruben Dario Triana.pdf
# Procesando: NicolasTovar_2024.pdf
# Procesando: Nicolas cardenas (2).pdf
# Procesando: Alan Jones-Frontend Engineer-Betsson Malta-Remoti.pdf
# Error al procesar Alan Jones-Frontend Engineer-Betsson Malta-Remoti.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Axel Sotelo-Frontend Engineer-Betsson Malta-Remoti.pdf
# Error al procesar Axel Sotelo-Frontend Engineer-Betsson Malta-Remoti.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV_Luis Hernandez_Software_Engineer.pdf
# Procesando: Valentina Robledo Monsalve - CV (1).pdf
# Procesando: c971ec9e-0c1d-4ce8-b284-ccee6d10eeeb_Julian Urrego - CV - ENG - 2024.pdf
# Procesando: Cv_DannyMora.pdf
# Procesando: CV-Hans Burbano.pdf
# Procesando: Danny Arevalo CV.pdf
# Procesando: Ricardo 2024 RESUME.pdf
# Procesando: Jose Rojas CV.pdf
# Procesando: Florencia Dutari - CV.pdf
# Procesando: Oscar Rojas - CV.pdf
# Procesando: CV Johnattan Zambrano-1.pdf
# Procesando: Eng - Maximiliano Carfora.pdf
# Procesando: WalterMacall-SrRN.pdf
# Procesando: ResumeL.pdf
# Procesando: Resume Mario Murillo-1.pdf
# Procesando: cv-guillermo-dolores-software-engineer-1 (1).pdf
# Procesando: CV_Enrich.pdf
# Procesando: CV - Jorge Hern†n Su†rez Osorio (2).pdf
# Procesando: resume-Nicolas-delaTorre.pdf
# Procesando: Julián-Granados-CV.pdf
# Procesando: HojaDeVida_JhonAlexanderLaraBarrera (2).pdf
# Procesando: CV_NicolasPenaArias.pdf
# Procesando: CV - Mauricio Penaranda - 2025 - New.pdf
# Error al procesar CV - Mauricio Penaranda - 2025 - New.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: cv_se_en_andrescanon.pdf
# Procesando: Byron Andrago CV.pdf
# Procesando: NADIA BASTIDAS (EN).pdf
# Error al procesar NADIA BASTIDAS (EN).pdf: '<' not supported between instances of 'datetime.datetime' and 'str'
# Procesando: Hector Bustamante - English CV (1).pdf
# Procesando: CV BrayanAndresCovariaEnglish.pdf
# Procesando: CV_Martin_Piovani_en.pdf
# Error al procesar CV_Martin_Piovani_en.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Daniel_Ruiz-CV (1).pdf
# Procesando: 14483303-Andres_Gomez_resume.docx (2) (1).pdf
# Procesando: AlmerIbarraResume (14).pdf
# Procesando: Mateus_Torquato_de_Medeiros.pdf
# Procesando: CV -Nicolás Castañeda.pdf
# Procesando: BBD1018F-127C-4C11-98CA-12E050D26B3B.pdf
# Procesando: CV ANDRES MARIN .pdf
# Procesando: 14955159-Curriculum vitae english (1).pdf
# Error al procesar 14955159-Curriculum vitae english (1).pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV_MATEO_HERRERA_BU_EN.pdf
# Procesando: Davinson - Resume (2).pdf
# Procesando: CV - SJG _ EN (3).pdf
# Procesando: HojadeVida.pdf
# Procesando: CV-Bruno Cassapula.pdf
# Procesando: CV - Andres Felipe Mejia.pdf
# Procesando: hdv-2023 (1).pdf
# Error al procesar hdv-2023 (1).pdf: division by zero
# Procesando: Resume (1).pdf
# Procesando: JOSE SEBASTIAN CARDONA QUICENO_eng.pdf
# Procesando: Jonathan Hinestroza Resumen.pdf
# Procesando: CV_Teresa Romero (1) (1).pdf
# Procesando: curriculum_vitae.pdf
# Procesando: CV JDavidAvendano (1).pdf
# Error al procesar CV JDavidAvendano (1).pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV_Julián_Sánchez_EN.pdf
# Procesando: Leon Matias Resume in Detail (1).pdf
# Procesando: 8A9EBB5F-08ED-4D90-92C2-72A9024C2A58.pdf
# Procesando: CV-CristianCastroArias2024.pdf
# Procesando: Daniel Naranjo Serrano.pdf
# Procesando: Rafael Lopez English CV.pdf
# Procesando: CAIO_ROLLA_RESUME_2022_EN.pdf
# Procesando: Davi Coelho Software Engineer.pdf
# Procesando: CV Maria Fernanda.pdf
# Procesando: Pum_CV.pdf
# Procesando: CV - Lourdes Valli.pdf
# Procesando: CV-Mateo.pdf
# Procesando: CV - Miguel Angel Mazacote.pdf
# Procesando: CV-Carlos Campo-2022-Ingles.pdf
# Procesando: CV-Carlos Eduardo Sousa.pdf
# Procesando: Christian Oporto-SWE-ZIP-Remoti.pdf
# Procesando: CV Giancarlo Solano.pdf
# Procesando: HV MICHAEL QUI•ONEZ EN (1).pdf
# Procesando: Davit_Yedigaryan_CV.pdf
# Error al procesar Davit_Yedigaryan_CV.pdf: division by zero
# Procesando: CV Carlos Medina.pdf
# Procesando: Caio Doneda- CV.pdf
# Error al procesar Caio Doneda- CV.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV+Jose+Luis+Urrea+2022_V-English+-+DevelopX.pdf
# Procesando: Resume.pdf
# Procesando: ECD9AA3D-A942-4BE3-8E4E-3BE716F5565D1.pdf
# Procesando: cv_Silvano Andre.pdf
# Procesando: OSCAR OSPINA CV ENG 2025docx.pdf
# Procesando: Resume-Franco-Cuadros.pdf
# Procesando: CV_Manuel_Yanez 2024.pdf
# Procesando: CV - Miguel Alejandro Cardona.pdf
# Procesando: CORRALES_FIERRO_CV.pdf
# Procesando: Agustin Castro CV.pdf
# Procesando: CV_AndresNieto-EN (1).pdf
# Procesando: CV Sergio ruben murua english.pdf
# Procesando: CV Andres Osorio Castro 2023.pdf
# Procesando: Amon Gabriel dos Santos Paiva- CV.pdf
# Error al procesar Amon Gabriel dos Santos Paiva- CV.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV-E.pdf
# Procesando: CV Felipe Miranda .pdf
# Procesando: CV Ian Fernando Román Macedo (1).pdf
# Procesando: CV DANIEL LEITAO VILAR.pdf
# Procesando: CV, Sept 2023_compressed (1).pdf
# Procesando: CV Juan Pablo Cardona.pdf
# Procesando: CV (JavaScript Full Stack Developer) (1).pdf
# Procesando: Ricardo 2024 RESUME (1).pdf
# Procesando: English CV-Victor Aguilarte.pdf
# Procesando: CV_Miguel_Camargo_2024 (2).pdf
# Error al procesar CV_Miguel_Camargo_2024 (2).pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Ronny-Carrasquel-.NET Developer.pdf
# Procesando: CV Vanessa Marely Aristizabal Angel - Frontend Engenieer - Betsson Malta - Remoti.pdf
# Procesando: MARTIN VILLA - CV - 2024.pdf
# Procesando: CV _Katerina_Poliakova (1).pdf
# Procesando: Francisco Gomez.pdf
# Error al procesar Francisco Gomez.pdf: '<' not supported between instances of 'datetime.datetime' and 'str'
# Procesando: CURRICULUM VITATE.pdf
# Procesando: CV Germán Javier Pérez González - Frontend engineer - Betsson Malta - Remoti.pdf
# Procesando: Rodrigo-Goncalves-Solidity - Yamata.pdf
# Procesando: resume (1) (1) (1).pdf
# Procesando: cv-juan-2024.pdf
# Error al procesar cv-juan-2024.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Daniel_Tapia_CV.pdf
# Procesando: Johannes Correa - CV (JTL).pdf
# Procesando: cv (10).pdf
# Procesando: CVAlvaroMartinez.pdf
# Procesando: Renan Soares - CV.pdf
# Procesando: John F Valencia C - Curri_culum.pdf
# Procesando: 5023CF7B-9C27-4C49-A03F-EB9193FAEBCD.pdf
# Procesando: PROFESSIONAL RESUME - DANIEL TORRES RUIZ (fixed).pdf
# Procesando: cv_hernan_parada_200424.pdf
# Procesando: Willmer Hernandez-Frontend Engineer-Betsson Malta-Remoti.pdf
# Error al procesar Willmer Hernandez-Frontend Engineer-Betsson Malta-Remoti.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: NodeJs + Angular Dev - Jorge Ricardo V (1).pdf
# Procesando: diegotorres.pdf
# Procesando: Juan Sebast Forero CV.pdf
# Procesando: JAVIER_ALMARIO-RESUME-2024 (1).pdf
# Procesando: CV_Sebastian_Ponce.pdf
# Procesando: CV Simon Hoyos.pdf
# Procesando: HVSaul (1).pdf
# Procesando: Maite Gracia - CV.pdf
# Procesando: RENATO VA_SQUEZ.pdf
# Error al procesar RENATO VA_SQUEZ.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV - Andres Chavez.pdf
# Error al procesar CV - Andres Chavez.pdf: division by zero
# Procesando: E99026B5-32A4-4099-9C5E-28BC4C16CA7B (1).pdf
# Error al procesar E99026B5-32A4-4099-9C5E-28BC4C16CA7B (1).pdf: division by zero
# Procesando: Resume Ezequiel Fornes  01-23.pdf
# Error al procesar Resume Ezequiel Fornes  01-23.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: hoja de vida alejandra leon pineda (1).pdf
# Procesando: Sergio Llanos Resume (1).pdf
# Procesando: CV_EN_Pablo_24D.pdf
# Procesando: CV Carlos Anguila.pdf
# Procesando: HojaVidaDiegoGarcia.pdf
# Procesando: Julio Ponce-CV.pdf
# Procesando: CV - Yaddy Rojas - ENG.pdf
# Procesando: Resume Lucas Trentin.pdf
# Procesando: CV_John+Alejandro+Duran+Garzon.pdf
# Procesando: Lucas Pinto- CV.pdf
# Procesando: CV Fabian Bareno.pdf
# Procesando: 1824E22D-3223-48D2-A3DE-3D358B73A528.pdf
# Procesando: Eylen-CV-2024.pdf
# Procesando: Yeison Jurado .pdf
# Procesando: CV-JSVA-2024-DEC (1).pdf
# Procesando: CV - Raul Santiago Agamez.pdf
# Procesando: Resume-Ivan-Dario-Rodriguez-Pascuas-ENG (2).pdf
# Procesando: HDV2021 (6).pdf
# Procesando: CV Damian Teplitz (1).pdf
# Procesando: Daniel Ria§o CV (1).pdf
# Procesando: Wilder Salgado Lopez CV.pdf
# Procesando: John Mejia CV.pdf
# Error al procesar John Mejia CV.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Ignacio Filippi - Frontend - Betsson Malta - remoti.pdf
# Procesando: Gustavo CV.pdf
# Procesando: Luis Meneses 2023.pdf
# Procesando: CV Ignacio.pdf
# Error al procesar CV Ignacio.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Luiz Fernando Abreu- CV.pdf
# Procesando: Elena Madalina - CV.pdf
# Procesando: CV_Jesus_David_Rodriguez.pdf
# Procesando: CV_ROBERTO_GUERRERO.pdf
# Procesando: CV Luis Eduardo Espinosa.pdf
# Procesando: CV Alejandro Benjumea.pdf
# Procesando: 92D64E7E-8203-4FB3-8D35-E144028788F9.pdf
# Procesando: Edinson Villalba.pdf
# Procesando: ResumeRNegrette.pdf
# Error al procesar ResumeRNegrette.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Eduardo Grajales Villanueva CV (2).pdf
# Procesando: Resume Eng. Neiro Diaz - CD.pdf
# Procesando: CV- Daniel Nagaoka- Frontend-Betsson Malta-Remoti.pdf
# Procesando: MarcoADuranP-CV.pdf
# Procesando: CV Daniel Puerto.pdf
# Procesando: Ivan Delgado.pdf
# Error al procesar Ivan Delgado.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Alex Diaz CV - 2022.pdf
# Procesando: Curriculum Vitae Matias Calvo (1).pdf
# Procesando: CV_2022 - EN.pdf
# Procesando: CV Frank Edward Daza Gonzalez.pdf
# Procesando: CV Ivan Garcia.docx (1) (1).pdf
# Procesando: Martin Castro CV - solidity yamata.pdf
# Procesando: CV - Andres VIllamil.pdf
# Error al procesar CV - Andres VIllamil.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV (2).pdf
# Procesando: Lionel's Resume - Passport.pdf
# Procesando: Spanish_CV_Esneider_Restrepo.pdf
# Procesando: Curriculo Lucca.pdf
# Procesando: EN_CV-leonardo-salazar-narvaez_2021.pdf
# Procesando: Bruno Silva - Solidity Yamata.pdf
# Procesando: Resume_Salvador_Lavariega_Sr Back End Developer_2024.pdf
# Procesando: CV_KAREN_HERRERA_23_nov.pdf
# Error al procesar CV_KAREN_HERRERA_23_nov.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: 32D78BE8-4267-4BF7-B736-A1C7567A2A5B.pdf
# Procesando: Parzifal_CV.pdf
# Procesando: jji.en.full.pdf
# Procesando: CV - Filipe Siciliano.docx.pdf
# Procesando: Geovanny Cartin.pdf
# Procesando: Resume - Marco Castiglione - Solidity Yamata.pdf
# Procesando: CV_2024_EN.pdf
# Procesando: Catalina-Grajales-resume.pdf
# Error al procesar Catalina-Grajales-resume.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Resume Kevin Espinoza - Frontend Developer (1).pdf
# Procesando: CV Juan Puerta.pdf
# Procesando: CV Ramiro (1).pdf
# Procesando: CV_AlejandroCastro_E.pdf
# Error al procesar CV_AlejandroCastro_E.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Resume Lucas Assmann.pdf
# Procesando: David malagon - CV.pdf
# Procesando: Miguel Angel Gomez.docx.pdf
# Procesando: HojaVida2022_CurriculumVitë.pdf
# Error al procesar HojaVida2022_CurriculumVitë.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CVJCOC.pdf
# Procesando: Resume Michael Romero .pdf
# Procesando: 08-2024-CV - Jakub Ozog (1).pdf
# Procesando: ECD9AA3D-A942-4BE3-8E4E-3BE716F5565D.pdf
# Procesando: CV - Juan Pablo Guirado.pdf
# Procesando: rguerrero resume 2024.pdf
# Procesando: Jean Misquez Resume.pdf
# Procesando: CV - Héctor Polanco (english).pdf
# Procesando: Christian_Blanco_CV_2022.pdf
# Procesando: Camilo Cetina - CV (FLE).pdf
# Procesando: Jhon Jairo Grajales Múnera - English - Extended - Last.pdf
# Procesando: CV - Jorge Hern†n Su†rez Osorio (22).pdf
# Procesando: Andres Torres CV.pdf
# Procesando: CV Gustavo Nunez Fullstack Engineer - Tenant Evaluation - Remoti.pdf
# Procesando: CV Jesus-Aguilar.pdf
# Procesando: alexis_pequeno_cv_en.pdf
# Error al procesar alexis_pequeno_cv_en.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: cv-juan__moreno-FE.pdf
# Procesando: CV - Santiago Ardila.pdf
# Procesando: Enrique Horta- CV.pdf
# Error al procesar Enrique Horta- CV.pdf: '<' not supported between instances of 'datetime.datetime' and 'str'
# Procesando: CV_Yefry_Lopez_2024_02_05.pdf
# Procesando: CVJohan.pdf
# Procesando: ABD57CA0-6506-4FF2-84B3-42F845509854.pdf
# Procesando: Hoja de vida Alejandro Londoño Pérez  2024.pdf
# Procesando: Jaqueline Kimmi Kirino -CV.pdf
# Procesando: CV - Diego Gutierrez (Full Experience).pdf
# Procesando: Java Software Developer.pdf
# Procesando: cv_wilson_castañeda.pdf
# Procesando: Emilio CV .pdf
# Procesando: Resume-David-Castañeda R.pdf
# Procesando: Carlos Pinto Jimenez_CV.docx.pdf
# Procesando: Juan José López Lira.pdf
# Procesando: Diego Remicio-Frontend Engineer-Betsson Malta-Remoti.pdf
# Procesando: CV Johan Andres Bustos Amaya.pdf
# Procesando: curriculum_vitae_ago_2022_ver_eng_extended.pdf
# Procesando: Sucre - Specialist Fullstack Developer-3.pdf
# Procesando: CV Marco Aguilera - Software developer_CA.pdf
# Procesando: Jhornan Colina Cv Vue.pdf
# Procesando: Curriculum Vitae (1).pdf
# Procesando: 15120649-CV - Oscar Rodríguez Beltrán.pdf
# Procesando: Jorge Astaiza CV_S (1).pdf
# Procesando: CV_OscarAmaya.pdf
# Error al procesar CV_OscarAmaya.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV-Andres-Betancourt.pdf
# Procesando: CV - Jesus Alejandro Vega.pdf
# Procesando: Diego Ferro - Frontend - Betsson Malta- remoti.pdf
# Error al procesar Diego Ferro - Frontend - Betsson Malta- remoti.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV - Luisny J Ugarte C (1).pdf
# Procesando: CV - Daniel Rios.pdf
# Procesando: Joaquin Herrera Gayol - CV (1).pdf
# Procesando: CV CLAUDIU_PAPARUZ.pdf
# Procesando: CV - JOSE BRICEN_O-2 (1).pdf
# Procesando: EDFF4983-EA09-4CB1-9B8F-E406B498DD31 (2).pdf
# Error al procesar EDFF4983-EA09-4CB1-9B8F-E406B498DD31 (2).pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Resume Sergio Terroso Fullstack Developer (1).pdf
# Procesando: Rj_Alves_Resume.pdf
# Error al procesar Rj_Alves_Resume.pdf: division by zero
# Procesando: CV - Richar Melo.pdf
# Procesando: CV-Chiocconi-YellowPepper (1).pdf
# Procesando: HV_MIGUEL_2024_1-2.pdf
# Procesando: CV Diego Urrego.pdf
# Procesando: CV_-_Adrian_Felipe_Cardona_Grajales_2023.pdf
# Error al procesar CV_-_Adrian_Felipe_Cardona_Grajales_2023.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: resume (1)-3(1).pdf
# Procesando: 11686212-CV-Jorge Vidal.pdf
# Procesando: CV Frederico.pdf
# Procesando: CV_Jhovanny Andres Suárez Arenas.pdf
# Procesando: CVJuanLeon-EN (1).pdf
# Procesando: CV_Andres_Felipe_Ceballos.pdf
# Procesando: cv2022november.pdf
# Error al procesar cv2022november.pdf: division by zero
# Procesando: Edison-Cv-DF- Español_N.pdf
# Procesando: Sergio Resume (2).pdf
# Procesando: 14503315-CV - Henry Luis Gomez Ortiz [En] (1) (1).pdf
# Procesando: Luis-Guillermo-Rossano-Esquivel-CV2024.pdf
# Error al procesar Luis-Guillermo-Rossano-Esquivel-CV2024.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: HojadevidaSteban24.pdf
# Procesando: Yonny_Nova_English (1).docx.pdf
# Procesando: Nelson Eduardo Arevalo Cubides (1).pdf
# Procesando: Jaime Alonso CV English.pdf
# Procesando: CV_E2023.pdf
# Procesando: CV_Sergio_Junco_DF9SE59.pdf
# Procesando: EE1F2E58-1C0E-44DB-8A7F-8ECA1D08835A.pdf
# Procesando: Alexandre Resume.pdf
# Procesando: CV - Jeudrin Al° Marchena S†nchez (1).pdf
# Procesando: LBD_CURRICULUM_1.docx (1).pdf
# Procesando: Resume_Sergio_Perez_2024 (1).pdf
# Procesando: CV Wilson Laguna English (3).pdf
# Error al procesar CV Wilson Laguna English (3).pdf: division by zero
# Procesando: cv_hugo_en.pdf
# Procesando: CV- Ruben Dario Triana.pdf
# Procesando: CV - Gonzalo Andrés Ramírez.pdf
# Procesando: VictorPietro_Reis_Resume (1).pdf
# Error al procesar VictorPietro_Reis_Resume (1).pdf: division by zero
# Procesando: 10967986-Boris Palacios_CV Mid level..pdf
# Procesando: CV (1) (1).pdf
# Procesando: Emanuel Frua-CV-Developer.pdf
# Procesando: Joaquin Garrido CV.pdf
# Procesando: CV Abner Cuellar.pdf
# Procesando: Curriculum Alberto Nin§o.pdf
# Error al procesar Curriculum Alberto Nin§o.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV - Bernard Contão - English.pdf
# Procesando: JH_CV_english_version-1 (2).pdf
# Procesando: Joao Vitor Passos-Frontend Engineer-Betsson Malta-Remoti.pdf
# Procesando: Lucas Gandara - Frontend - Betsson Malta - remoti.pdf
# Procesando: Santiago Florez Giraldo CV.pdf
# Procesando: Kevin Lain Sierra- Frontend Developer React.pdf
# Procesando: CV+Fidel+Caicedo+2023 Back End.pdf
# Error al procesar CV+Fidel+Caicedo+2023 Back End.pdf: '<' not supported between instances of 'datetime.datetime' and 'str'
# Procesando: Resume-Jefferson-Medina-2-1.pdf
# Procesando: Maicon Heredez- CV.pdf
# Procesando: Oscar Cantillo - Frontend - Betsson Malta - remoti.pdf
# Procesando: CV-Ricardo-Delgado-En.pdf
# Procesando: CVMartinAlbarracin (5).pdf
# Error al procesar CVMartinAlbarracin (5).pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: ResumeL.pdf
# Procesando: Naren Avila - Lead Software Engineer.pdf
# Procesando: Jonathan Bolanos - CV (JTL).pdf
# Procesando: CV Francisco Updated.pdf
# Error al procesar CV Francisco Updated.pdf: '<' not supported between instances of 'datetime.datetime' and 'str'
# Procesando: Daniel Vasques CV.pdf
# Procesando: Edwar Gomez (2).pdf
# Procesando: CV Nesly Castro - 2025-01.pdf
# Procesando: CV Javier Rocha-2 (1).pdf
# Procesando: CV_DARÍO_VALAREZO.pdf
# Procesando: CV- Felipe Costa Reis.pdf
# Procesando: CV_Byan_Romero_Front_End_Developer.pdf
# Procesando: 2B7FFB7D-6338-4291-9A76-61E9AC9C29FB (1).pdf
# Procesando: Salomon_Mejia_CV (1).pdf
# Procesando: Muhammad-Shahzad-Angular-Developer (2).pdf
# Procesando: Diego Vielma CV-07-2024.pdf
# Procesando: Jhonattan_Fernandez_Vargas.pdf
# Error al procesar Jhonattan_Fernandez_Vargas.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV NELSON_OSORIO_CV.pdf
# Procesando: Resume John Calderon (1).pdf
# Procesando: CV PabloUrrizaIricibar (1).pdf
# Procesando: CV_ANYI_JARMILLO.pdf
# Procesando: DavidMoralesCV.pdf
# Error al procesar DavidMoralesCV.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Daniel_Ruiz-CV (1).pdf
# Procesando: cv (1).pdf
# Error al procesar cv (1).pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Pedro Ramón Casanova - CV.pdf
# Procesando: CV_FlavioLunaPino_FullStackDeveloper_Net_Angular.pdf
# Procesando: CV_Gerson_Garrido (4).pdf
# Procesando: 14305073-CV_DavidRueda (2).pdf
# Procesando: CV_EN_DANIELA_RAMIREZ_GOMEZ (1).pdf
# Procesando: CV_Vickler Charles.pdf
# Procesando: CV DiegoCastro Eng.pdf
# Procesando: CV[Regino Ballester Camús].pdf
# Procesando: Andres Mechali - CV.pdf
# Error al procesar Andres Mechali - CV.pdf: division by zero
# Procesando: CV_MATEO_HERRERA_BU_EN.pdf
# Procesando: CV_ELVIS_ESPINOZA(19November2022).pdf
# Procesando: CV DIEGO RAMIREZ.pdf
# Procesando: CV Diego Ospina.pdf
# Procesando: CV-Bruno Cassapula.pdf
# Procesando: CV - Yeison Caicedo.pdf
# Procesando: formal JS Resume - freelance.pdf
# Procesando: Hoja de Vida MACH.pdf
# Procesando: Jonathan Hinestroza Resumen.pdf
# Procesando: Calciano Federico resume (1).pdf
# Procesando: Resume-Mario-Ricardo-Domi_nguez-Quiroz.pdf
# Error al procesar Resume-Mario-Ricardo-Domi_nguez-Quiroz.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV Juan_Camilo_Martinez (1).pdf
# Procesando: CV Hector Silvar.pdf
# Procesando: Yeison_Arango_Zapata_-_Front-End_Developer.pdf
# Procesando: Curriculum Vitae - Cristian Geovany Arias Castro 2024 (1).pdf
# Procesando: HV_DAVID_RUIZ.pdf
# Procesando: F3EDF262-8070-435C-926F-AFAB641CA840.pdf
# Error al procesar F3EDF262-8070-435C-926F-AFAB641CA840.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Curriculum vitae - Facundo Rodriguez.pdf
# Procesando: CV Guillermo.pdf
# Procesando: CV- Fabian AndrÇs Alvarez Hoyos.pdf
# Procesando: Sintesis_Curricular_Luis_Malpica_Murillo.pdf
# Procesando: EB9B983B-17DC-4976-B0DA-DD45C0699E95 (1).pdf
# Procesando: Ricardo_Luna_Resume.pdf
# Procesando: German Gustavo Bertea - CV .pdf
# Procesando: Jose Vizcaino - Frontend - Betsson Malta - remoti 2.pdf
# Procesando: D0173A82-0F1B-474B-8168-1564BC5EC6B9 (3).pdf
# Error al procesar D0173A82-0F1B-474B-8168-1564BC5EC6B9 (3).pdf: '<' not supported between instances of 'datetime.datetime' and 'str'
# Procesando: CVMiguel_compressed (1) (1).pdf
# Error al procesar CVMiguel_compressed (1) (1).pdf: division by zero
# Procesando: HV_pabloVelilla-info_english.pdf
# Procesando: CV-CristianCastroArias2024.pdf
# Procesando: CV Diego Labastida 2022 (1).pdf
# Procesando: Gerlis_Alvarez_Cardona_-_Web_developer.pdf
# Procesando: Victor Colodrero - CV .pdf
# Procesando: Jaime Cadena (2).pdf
# Procesando: CV_Andres_Ariza_ATS (2).pdf
# Error al procesar CV_Andres_Ariza_ATS (2).pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Hernan_Zerrizuela_Resume.pdf
# Procesando: CV - Oscar Castaneda (1).pdf
# Error al procesar CV - Oscar Castaneda (1).pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Resume_eng.pdf
# Error al procesar Resume_eng.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Alvaro Cruz - Resume.pdf
# Procesando: Felipe Nari§o - CV (JTL).pdf
# Procesando: EnglishCv.pdf
# Procesando: CV_ARNOLD_GAMARRA(ENGLISH).pdf
# Procesando: Cv Juan Felipe Areiza Monsalve.pdf
# Procesando: Eduardo Muñoz -- Resume.pdf
# Error al procesar Eduardo Muñoz -- Resume.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: cv - jose nicolas garcia pineda (1) (1).pdf
# Procesando: Juan Gonzalo Isaza-Frontend Engineer-Betsson Malta-Remoti.pdf
# Procesando: jesus serrano cv (1).pdf
# Procesando: HV-JDR-ENGLISH.pdf
# Procesando: DAVID MADRID resume.pdf
# Procesando: HojaVidaRobinsonB.pdf
# Procesando: Hoja_vida.pdf
# Procesando: CV-EN-David_Hernandez.pdf
# Procesando: CV - Cesar Colorado - Sr Java Developer - Spectar.pdf
# Error al procesar CV - Cesar Colorado - Sr Java Developer - Spectar.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV_NestorJulianMolina.pdf
# Procesando: CV-Jorge-Eliecer-Mun_oz-Herrera-ENGLISH (1).pdf
# Procesando: 13984773-Twenty-Seconds_cv-7.pdf
# Procesando: Resume.pdf
# Procesando: C5392280-FB45-412D-B335-20072967CE24 (1).pdf
# Procesando: cv_english_carlos_maturana_ (1).pdf
# Procesando: Daniel_Castellanos_-_Senior_Software_Developer-2.pdf
# Procesando: Resume_Marcelo_Rizzardo_Lima.pdf
# Procesando: cv_Silvano Andre.pdf
# Procesando: Adam Kisorsi CV.pdf
# Procesando: CV María Castro English.pdf
# Procesando: 0A6555DA-BEF3-4946-90A4-B0ED1A3C0DBA (1).pdf
# Procesando: CV Jose Pedroza .pdf
# Procesando: CV_Danny_Alexander_Trujillo.pdf
# Procesando: federicoCV.pdf
# Procesando: CV AGPJ.pdf
# Procesando: CV Juan E. Silva M.-2-1.pdf
# Procesando: Rafael Sousa - CV.pdf
# Error al procesar Rafael Sousa - CV.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV_AlvaroHerrero.pdf
# Procesando: CV-3.pdf
# Procesando: Cv_Desarrolladora Software_ElianaSuancha.pdf
# Procesando: Bryan Resume.pdf
# Procesando: Resume Andres Rivera (1).pdf
# Procesando: Main CV Carlos Castro - English.pdf
# Procesando: CV Jose Alejandro Moreno  - Frontend engineer - Betsson Malta - Remoti.pdf
# Procesando: AldoIGCV.pdf
# Procesando: CV - Santiago Guerra Garrote.pdf
# Procesando: Carlos_JosÇ_CortÇs_Rivera_-_Developer_And_Scrum_Master_Project_Manager.pdf
# Procesando: CV_eloi_valles_English.pdf
# Procesando: CV OSCAR PASTRANAdocx (1).pdf
# Procesando: CV - Angel Ramos 2024.pdf
# Procesando: English_ CV_Bruna_Bertolini_Correia (1) (1) (2).pdf
# Procesando: ResumeHannahNJ.pdf
# Procesando: Matthew Seidel - CV Fullstack developer.pdf
# Error al procesar Matthew Seidel - CV Fullstack developer.pdf: division by zero
# Procesando: RudyLuis_HernndezAvila.pdf
# Error al procesar RudyLuis_HernndezAvila.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV - Josimar Sanchez - Sr Java Developer - Spectar.pdf
# Procesando: JuanGRomeroS.pdf
# Procesando: CV - Edisson Ruiz.pdf
# Procesando: AndresGironAngulo (1).pdf
# Procesando: CV Ronaldo Geldres.pdf
# Procesando: 2FD690E9-B709-4A3A-B1C1-66C0AA76269Edocx.pdf
# Procesando: Rafael_Parra_Eng (1).pdf
# Procesando: Pedro Merino Resume 2024 (1).pdf
# Procesando: CV Andres Bolivar eng .pdf
# Procesando: CV Ashmed Diaz 2024-Sp (3).pdf
# Procesando: CV-2023-Johan-Mendez-sr-Frontend-developer.pdf
# Procesando: CURRICULUM VITATE.pdf
# Procesando: Brayan Backend - CV.pdf
# Error al procesar Brayan Backend - CV.pdf: division by zero
# Procesando: CV_GUSTAVO_GUERRERO.pdf
# Procesando: CV Santiago Martínez - Fullstack Engineer - Tenant Evaluation - Remoti.pdf
# Procesando: CV Jonathan Martinez.pdf
# Procesando: CV Hader.pdf
# Procesando: CV - Tito Barbosa Rezende.pdf
# Procesando: CV_JUAN_VARGAS_MM (2).pdf
# Procesando: CV_Christian_Piedra.pdf
# Procesando: Humberto-Mangino-Full-Stack-0324.pdf
# Procesando: Cv Juan Felipe Areiza Monsalve 2.pdf
# Procesando: CV - Brandon Andrés Vargas Piñeros.pdf
# Procesando: Hoja de Vida.pdf
# Procesando: CandalesV2.pdf
# Procesando: ResumeJobDetail.docx.pdf
# Procesando: CVToSendAct2 (2).pdf
# Procesando: CV  AndrÇs S†nchez(act).pdf
# Procesando: Hoja de Vida Andres.pdf
# Procesando: Carlos_Zerga_Resume.pdf
# Procesando: Carlos Arenas - Resume .pdf
# Error al procesar Carlos Arenas - Resume .pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV - Yesith Valencia (1).pdf
# Procesando: 1F31C18F-CCD9-440B-AD0A-78BA5DE7C408.pdf
# Procesando: Oscar Valencia-ResumeOct2022 (1).pdf
# Procesando: Matias Ferrero Vilas - English.pdf
# Procesando: CV (4).pdf
# Procesando: GERMÁN OVALLE SILVA.pdf
# Procesando: Cv_2023.pdf
# Procesando: CV- Andres Santacruz ING 10-2024.pdf
# Procesando: Jose Vizcaino - Frontend - Betsson Malta - remoti.pdf
# Procesando: FRONT-END CV SEBASTIÁN SALAZAR (1).pdf
# Procesando: _Resume Fernando Gaona Juarez 2024_Javax (2).pdf
# Procesando: Sergio Llanos Resume (1).pdf
# Procesando: 96F01412-FC87-4288-971E-87C60481ACA0 (2).pdf
# Procesando: Andres-Arredondo-CV (1).pdf
# Procesando: cv - Luis Miguel Gallegos.pdf
# Procesando: CV_AndresBaquero.pdf
# Procesando: CV copy.pdf
# Procesando: Jose_Vergara_CV.pdf
# Procesando: CV_Wilhelm Steven Boada.pdf
# Procesando: CV Yomar Miranda_ Sr. React _ Spectar.pdf
# Procesando: 4221F539-1C32-4D76-9C55-5FD31316D509 (1).pdf
# Procesando: CV Nicolás Góngora.pdf
# Procesando: Carlos Reta - Lead Frontend Passport.pdf
# Procesando: Jonathan_Camilo_Narvaez_Martinez _ EN.pdf
# Procesando: cv_zuly_alcaraz_2022.pdf
# Procesando: CV Frontend Mauricio Salazar (3).pdf
# Procesando: CV Juan Saavedra Spanish (2).pdf
# Procesando: D9FFD194-3F89-4EA0-9D76-13DD671F267A (1).pdf
# Procesando: CV_English_Lizeth_1.pdf
# Procesando: Marcelo_Fabricio_de_Mello_-_Software_Developer.pdf
# Procesando: resume Julian Andres Roman CV.pdf
# Procesando: Curr°culum_0924.pdf
# Procesando: CV Luis J Jimenez N.pdf
# Procesando: COPY+OF+Resume-Mateo-Zapata-Caraballo.pdf
# Error al procesar COPY+OF+Resume-Mateo-Zapata-Caraballo.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Guillermo_Forero_Frontend_CV.pdf
# Error al procesar Guillermo_Forero_Frontend_CV.pdf: '<' not supported between instances of 'datetime.datetime' and 'str'
# Procesando: CV_Juan_Amell_ENG (1).pdf
# Procesando: FernandoBecerra_Resume (1).pdf
# Procesando: Joan Resume 2022.pdf
# Procesando: F03CAA7C-DDEC-49CA-8CE2-8C4D1BC0E815.pdf
# Error al procesar F03CAA7C-DDEC-49CA-8CE2-8C4D1BC0E815.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: New_Hoja_de_Vida_Andres__English_ (1).pdf
# Procesando: HANSEL JUNIOR OSPINO ORELLANO - RESUME (1).pdf
# Procesando: Alejandro Arevalo Vasquez Resume (March 2024) (1).pdf
# Procesando: CV Jaime Gómez Villamizar - Frontend engineer - Betsson Malta - Remoti.pdf
# Procesando: MartinBravo-Resume.pdf
# Procesando: CV Felipe Manrique 2022 EN.pdf
# Procesando: Felipe Valencia - CV .pdf
# Error al procesar Felipe Valencia - CV .pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV-DiegoAlzateATS (1).pdf
# Procesando: Fermin Diaz CV.pdf
# Procesando: Igor_cv.pdf
# Procesando: CV_Juan_Andrés_Méndez_Galvis_Jan_2025.pdf
# Procesando: CV-2023-07-25.pdf
# Procesando: CV_SantiagoMorales_JavaDev2024_ (2).pdf
# Procesando: AndresDavidGaitanCv.pdf
# Procesando: CV Alejandro Benjumea.pdf
# Procesando: Resume-Erik-Galiana-Farell.pdf
# Error al procesar Resume-Erik-Galiana-Farell.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV Brenda Yadira Gomez Sanchez 2024.pdf
# Procesando: sebastian-mera-resume-08-24.pdf
# Error al procesar sebastian-mera-resume-08-24.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Jhoner_Silva_Resume.pdf
# Procesando: Profile Teja Manikanta Gorantla.pdf
# Procesando: CV_CristianCuevas_2024_EN.pdf
# Procesando: C0D8DA19-71CE-434D-8E20-F2E2CCE52B93 (1).pdf
# Procesando: cv_eduardo_aragon.pdf
# Error al procesar cv_eduardo_aragon.pdf: division by zero
# Procesando: Eileen Guerrero HV - English.pdf
# Procesando: Resume_JohanVargas.pdf
# Error al procesar Resume_JohanVargas.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Renato Yanez Frontend Resume.pdf
# Procesando: Gabriela Quintanilla CV (3).pdf
# Procesando: cv - Noe.pdf
# Procesando: CV_DavidGuevaraMayorga_en- (1).pdf
# Procesando: CV-IngenieroDesarrolloSoftware-RogerMontoya.pdf
# Procesando: Resume-Juan-Antonio-Casillas-Aguiar.pdf
# Procesando: Lopez+Alan+-+CV.pdf
# Procesando: CV Julian Sanchez.pdf
# Procesando: C.V_CAMILO_MORAN_ENGLISH_VERSION.docx-1.pdf
# Procesando: ResumeYeisonRuizAug2024 (3).pdf
# Procesando: PROFESSIONAL RESUME - Juan Camilo.pdf
# Procesando: CV Victor.pdf
# Procesando: CV-Pablo S Rodriguez-En-2022 (3) (1) (1).pdf
# Procesando: CV-Fabian_Parra_English (1).pdf
# Procesando: CV Juan_Manuel_Kelsy_Romero.pdf
# Procesando: CV_MarcelaCa§onVargas.pdf
# Procesando: Fabricio Filipe Viapiana - CV.pdf
# Procesando: CV Cristian Perez English 2024.pdf
# Procesando: Dusting Posso CV 2023.pdf
# Procesando: CV - Alejandro Aguilar.pdf
# Procesando: Marc Romo - CV.pdf
# Procesando: Boris Palacios - 2024.fi.pdf
# Procesando: Mateo Castaño - Frontend Lead - Passport.pdf
# Procesando: CvJorgeAcevedo-1.pdf
# Error al procesar CvJorgeAcevedo-1.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Pawel-Forynski-US-EU.pdf
# Error al procesar Pawel-Forynski-US-EU.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV JEAN QUIROZ SANCHEZ.pdf
# Procesando: 2024_Cristian_EN_CV.pdf
# Error al procesar 2024_Cristian_EN_CV.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Miguel Chirino - CV.pdf
# Procesando: Resume (5).pdf
# Procesando: Julian CV .pdf
# Procesando: cv_manuel_bonilla_en_version.pdf
# Procesando: Mateus Melo - solidity .pdf
# Procesando: CV Ramiro (1).pdf
# Procesando: CV_AlejandroCastro_E.pdf
# Error al procesar CV_AlejandroCastro_E.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Esteban_Gulias_CV__.pdf (1).pdf
# Procesando: CV -- MaicolDuque.pdf
# Error al procesar CV -- MaicolDuque.pdf: '<' not supported between instances of 'datetime.datetime' and 'str'
# Procesando: CV_Cristian_Lopez__YS6ReUv.pdf
# Procesando: CV-SSE (1).pdf
# Procesando: CV Diego A (1).pdf
# Procesando: CV Christian Rodriguez 10-10-2024-English.pdf
# Procesando: Johan-Sebastian-Vargas-Rodriguez-Resume.pdf
# Procesando: HojaVida2022_CurriculumVitë.pdf
# Error al procesar HojaVida2022_CurriculumVitë.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV-Luis-Leon-Ramirez.pdf
# Procesando: João Ventura - Frontend - Betsson Malta - remoti.pdf
# Procesando: ricardo_delarosa_march_20th_2024.fi (1).pdf
# Procesando: Jose_Mario_Chaves.pdf
# Procesando: CV Profesional (4) (1).pdf
# Error al procesar CV Profesional (4) (1).pdf: '<' not supported between instances of 'datetime.datetime' and 'str'
# Procesando: CV Gabriel Lucena.pdf
# Procesando: Navarro Moises_Java backend Dev (2).pdf
# Procesando: alberto_moreno_cv.pdf
# Procesando: AndrÇs Acosta CV-1.pdf
# Procesando: Yamid Granda - Senior Front-End Engineer.docx.pdf
# Procesando: CV AG REACT MARCH 2024.pdf
# Procesando: CV-AbrahamHernandez-Ingles.pdf
# Procesando: ManuelGutierrezCV.pdf
# Error al procesar ManuelGutierrezCV.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV Luis J Jimenez N (1).pdf
# Procesando: FelipeSantanaCV-2025R.pdf
# Procesando: EMANUEL_LEDESMA_ARREOLA _RESUME.pdf
# Procesando: 14470412-CV - Guido Mantilla.docx (1).pdf
# Procesando: Curriculum Vitae-202404-April.pdf
# Procesando: Jonathan Amaya CV.pdf
# Procesando: Ouassim El Yahyati - CV  .pdf
# Procesando: CV Ricardo Diaz _ Sr.React _ Spectar.pdf
# Procesando: Resume_FrancoGarciaGonzalez-.pdf
# Procesando: Jose Fernandez.pdf
# Procesando: CV_Breymer_Robles.pdf
# Procesando: C78F729C-0C16-471A-9D60-D1BE71D46D6B.pdf
# Procesando: Andres Felipe Gonzalez - Resume.pdf
# Procesando: Nicolas_Palacio_Resume.pdf
# Procesando: OrlandoSu†rezCV-1-1 (1).pdf
# Procesando: CV Ivan Perez-02.pdf
# Procesando: Antonio Casas.pdf
# Procesando: CVJLuna25.pdf
# Procesando: CV - Eng (Alejandro Cano).pdf
# Error al procesar CV - Eng (Alejandro Cano).pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: CV Juan Camilo Mora _ Sr. React _ Spectar.pdf
# Procesando: 97E3F7A7-E173-46A4-93DE-B3860839A891 (2).pdf
# Procesando: patricio_cv_en_2022 (3) (1).pdf
# Procesando: CV-Javier2024Es (1).pdf
# Procesando: CV di Napoli Franco.pdf
# Procesando: hv_ingles_Felipe.pdf
# Procesando: William Andres Rodriguez - Frontend - betsson Malta - remoti.pdf
# Procesando: Gabriel Bernal Resume FP.pdf
# Error al procesar Gabriel Bernal Resume FP.pdf: division by zero
# Procesando: CV.pdf
# Procesando: 3CB7A093-2EB1-469E-9F8B-117A64D6754D (3).pdf
# Error al procesar 3CB7A093-2EB1-469E-9F8B-117A64D6754D (3).pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Carlos Pinto Jimenez_CV.docx.pdf
# Procesando: PepeResumeA-1-1 (1).pdf
# Procesando: LUIS FELIPE MOCTEZUMA RUIZ-CV.pdf
# Error al procesar LUIS FELIPE MOCTEZUMA RUIZ-CV.pdf: '<' not supported between instances of 'str' and 'datetime.datetime'
# Procesando: Mauro OLSEN CV.pdf
# Procesando: Daniel's CV 2022 Spanish.pdf

# %%
df_CVs_exitosos
# Out:
#                                                Archivo  Páginas  \
# 0                          Lucas Visentin - Resume.pdf        2
# 1             CV Milton Ivan Martinez Gonzalez (1).pdf        6
# 2                              CV - Andrea Martins.pdf        1
# 3                           Resume Hector Bedoya L.pdf        1
# 4    985269fa-a528-46aa-bc9c-403ee23fbcd3_CV Felipe...        4
# ..                                                 ...      ...
# 232                   Carlos Pinto Jimenez_CV.docx.pdf        6
# 233                           Juan José López Lira.pdf        7
# 234  Diego Remicio-Frontend Engineer-Betsson Malta-...        1
# 235                   CV Johan Andres Bustos Amaya.pdf        2
# 236     curriculum_vitae_ago_2022_ver_eng_extended.pdf        2
#
#                        Orden Cronológico Formato de Texto  \
# 0                      Orden Cronológico          Viñetas
# 1                      Orden Cronológico            Mixto
# 2                      Orden Cronológico          Viñetas
# 3                      Orden Cronológico          Viñetas
# 4                      Orden Cronológico          Viñetas
# ..                                   ...              ...
# 232                    Orden Cronológico          Viñetas
# 233                    Orden Cronológico          Viñetas
# 234  No se detectaron suficientes fechas          Viñetas
# 235                    Orden Cronológico          Viñetas
# 236                    Orden Cronológico            Mixto
#
#      Densidad de Información  Cantidad de Palabras  education  \
# 0                      18.20                   493       True
# 1                      20.20                  1674       True
# 2                      18.91                   388      False
# 3                      23.60                   378       True
# 4                      12.22                   695       True
# ..                       ...                   ...        ...
# 232                    13.51                  1379       True
# 233                     8.91                   699       True
# 234                    23.55                    77      False
# 235                    17.54                   673      False
# 236                    15.52                  1412       True
#
#      work_experience  skills  certifications  ...  Tamaño de fuente más usado  \
# 0               True    True            True  ...                        12.0
# 1               True   False            True  ...                        12.0
# 2              False    True           False  ...                         9.0
# 3               True    True           False  ...                        10.1
# 4              False   False           False  ...                        10.0
# ..               ...     ...             ...  ...                         ...
# 232             True    True            True  ...                        11.0
# 233             True    True           False  ...                        12.0
# 234             True   False           False  ...                         9.0
# 235             True   False           False  ...                         7.4
# 236             True    True            True  ...                         6.0
#
#      Legibilidad  Uso de negritas  Uso de cursivas  \
# 0          Buena               96               35
# 1          Buena               52               64
# 2     Deficiente                0                0
# 3          Buena               53                0
# 4          Buena              111                0
# ..           ...              ...              ...
# 232        Buena              342              173
# 233        Buena                4                0
# 234   Deficiente               32               10
# 235   Deficiente              199                0
# 236   Deficiente               47                0
#
#      Uso de colores (excluyendo fondo blanco y links)  \
# 0                                                  Sí
# 1                                                  No
# 2                                                  Sí
# 3                                                  Sí
# 4                                                  Sí
# ..                                                ...
# 232                                                Sí
# 233                                                Sí
# 234                                                Sí
# 235                                                Sí
# 236                                                Sí
#
#      Porcentaje de color real en la CV  Cantidad de imágenes o gráficos  \
# 0                                0.11%                                0
# 1                                 0.0%                                1
# 2                               32.12%                                9
# 3                                0.98%                                0
# 4                                3.51%                                3
# ..                                 ...                              ...
# 232                              0.08%                                8
# 233                               1.9%                               25
# 234                              1.37%                                0
# 235                              1.05%                                2
# 236                              1.27%                                0
#
#     Alineación principal  Consistencia de tamaños Consistencia de márgenes
# 0            Justificado            Inconsistente              Consistente
# 1            Justificado              Consistente            Inconsistente
# 2            Justificado              Consistente              Consistente
# 3            Justificado            Inconsistente              Consistente
# 4            Justificado            Inconsistente            Inconsistente
# ..                   ...                      ...                      ...
# 232          Justificado            Inconsistente            Inconsistente
# 233          Justificado            Inconsistente              Consistente
# 234          Justificado            Inconsistente              Consistente
# 235          Justificado            Inconsistente              Consistente
# 236          Justificado            Inconsistente              Consistente
#
# [237 rows x 28 columns]

# %%
df_CVs_no_exitosos
# Out:
#                                            Archivo  Páginas  \
# 0     Sucre - Specialist Fullstack Developer-3.pdf        6
# 1    CV Marco Aguilera - Software developer_CA.pdf        7
# 2                        Jhornan Colina Cv Vue.pdf        1
# 3                         Curriculum Vitae (1).pdf        3
# 4      15120649-CV - Oscar Rodríguez Beltrán.pdf        6
# ..                                             ...      ...
# 315                                         CV.pdf        1
# 316               Carlos Pinto Jimenez_CV.docx.pdf        6
# 317                        PepeResumeA-1-1 (1).pdf       10
# 318                             Mauro OLSEN CV.pdf        1
# 319                   Daniel's CV 2022 Spanish.pdf        4
#
#      Orden Cronológico Formato de Texto  Densidad de Información  \
# 0    Orden Cronológico          Viñetas                    17.81
# 1    Orden Cronológico          Viñetas                    16.68
# 2    Orden Cronológico          Viñetas                    17.29
# 3    Orden Cronológico          Viñetas                    16.08
# 4    Orden Cronológico          Viñetas                    12.08
# ..                 ...              ...                      ...
# 315  Orden Cronológico          Viñetas                    14.13
# 316  Orden Cronológico          Viñetas                    13.51
# 317  Orden Cronológico            Mixto                    22.50
# 318  Orden Cronológico          Viñetas                    13.04
# 319  Orden Cronológico            Mixto                    22.97
#
#      Cantidad de Palabras  education  work_experience  skills  certifications  \
# 0                    1471       True             True    True           False
# 1                    2111       True             True    True            True
# 2                     321       True             True   False           False
# 3                     642       True             True   False           False
# 4                     753       True            False   False            True
# ..                    ...        ...              ...     ...             ...
# 315                   169       True             True   False           False
# 316                  1379       True             True    True            True
# 317                  3729       True            False    True            True
# 318                   185       True             True    True           False
# 319                  1237      False             True   False            True
#
#      ...  Tamaño de fuente más usado  Legibilidad  Uso de negritas  \
# 0    ...                        11.0        Buena              137
# 1    ...                         9.0   Deficiente               86
# 2    ...                         8.6   Deficiente               70
# 3    ...                         9.8   Deficiente              112
# 4    ...                        11.0        Buena              357
# ..   ...                         ...          ...              ...
# 315  ...                         9.1   Deficiente                4
# 316  ...                        11.0        Buena              342
# 317  ...                        11.0        Buena              147
# 318  ...                         9.9   Deficiente                0
# 319  ...                        11.0        Buena              143
#
#      Uso de cursivas  Uso de colores (excluyendo fondo blanco y links)  \
# 0                107                                                Sí
# 1                 56                                                Sí
# 2                  0                                                Sí
# 3                  0                                                Sí
# 4                211                                                Sí
# ..               ...                                               ...
# 315                0                                                Sí
# 316              173                                                Sí
# 317              148                                                Sí
# 318                0                                                Sí
# 319                0                                                Sí
#
#      Porcentaje de color real en la CV  Cantidad de imágenes o gráficos  \
# 0                                0.13%                                3
# 1                                0.15%                                0
# 2                                2.46%                                1
# 3                               13.22%                               19
# 4                                0.79%                                5
# ..                                 ...                              ...
# 315                             13.65%                                1
# 316                              0.08%                                8
# 317                              1.18%                                1
# 318                             13.61%                                0
# 319                              0.66%                                2
#
#     Alineación principal  Consistencia de tamaños Consistencia de márgenes
# 0            Justificado            Inconsistente            Inconsistente
# 1            Justificado            Inconsistente            Inconsistente
# 2            Justificado            Inconsistente              Consistente
# 3            Justificado            Inconsistente            Inconsistente
# 4            Justificado              Consistente            Inconsistente
# ..                   ...                      ...                      ...
# 315          Justificado            Inconsistente              Consistente
# 316          Justificado            Inconsistente            Inconsistente
# 317          Justificado            Inconsistente            Inconsistente
# 318          Justificado            Inconsistente              Consistente
# 319          Justificado              Consistente            Inconsistente
#
# [320 rows x 28 columns]
